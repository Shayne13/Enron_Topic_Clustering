# %%
import sys, os, re, operator
import nltk
from Textrank import textrank
from Textrank.Units import EmailUnit, SentenceUnit
from util.Timer import Timer
from nltk import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD
from sklearn.cluster import spectral_clustering, AffinityPropagation, MeanShift
# from sklearn.decomposition import PCA
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# Loading Sentence Detector and Stop Words List
sentenceDetector = nltk.data.load('tokenizers/punkt/english.pickle')
stopwords = stopwords.words('english')

# %%
# Yields all non-hidden files/subdirectories in a directory.
def listdir_nohidden(path):
    for f in os.listdir(path):
        if not f.startswith('.'):
            yield '{0}/{1}'.format(path, f)

# %%
# Takes in an emails file path and the account owner and returns the EmailUnit.
def parseEmail(path, owner):
    
    with open(path, 'r') as f:
        contents = [l for l in f]
    
    # Lines that match these regexes should be removed:
    removeRegex = "({0})".format("|".join(['----------------------\sForwarded\sby',
                                            '-----Original\sMessage-----',
                                            'From:\s',
                                            'Sent:\s',
                                            'To:\s',
                                            'cc:\s',
                                            'bcc:\s',
                                            '[IMAGE]',
                                            'Subject:\s',
                                           ]))
        
    # Find the line numbers of the corresponding fields:
    senderIndex = [i for i, l in enumerate(contents) if re.search('(From:)', l)][0]
    recipientIndex = [i for i, l in enumerate(contents) if re.search('(X-To:)', l)][0]
    subjectIndex = [i for i, l in enumerate(contents) if re.search('(Subject:)', l)][0]
    textIndex = [i for i, l in enumerate(contents) if re.search('(X-FileName:)', l)][0] + 2
    
    # Extract Email metadata:
    sender = re.search('(From:\s)([^\n]+)', contents[senderIndex]).group(2).strip()
    recipient = re.search('(To:\s)([^\n]+)', contents[recipientIndex]).group(2).strip()
    subject = re.search('(Subject:\s)([^\n]+)', contents[subjectIndex]).group(2).strip()
    body = contents[textIndex:]
    
    cleaned = filter(lambda l: re.search(removeRegex, l), body)
    text = " ".join([subject] + contents[textIndex:]).replace("\n", "").strip()
    
    words = word_tokenize(text)
    processed = " ".join([ w for w in words if w not in stopwords ])
    
    return EmailUnit(owner, sender, recipient, subject, text, processed)

# %%
# Takes in the root path to an email account and returns all EmailUnits in that account.
def parseEmailAccount(root):
    emailPaths = [path for direc in listdir_nohidden(root) for path in listdir_nohidden(direc)]
    emails = filter(None, [parseEmail(path, root[root.rfind('/') + 1:]) for path in emailPaths])
    return emails

# %%
emails = parseEmailAccount("../Data/allen-p")
vectorizer = CountVectorizer(min_df=1)
corpus = [email.text for email in emails]
processedCorpus = [email.processed for email in emails]

X = vectorizer.fit_transform(processedCorpus)
feature_names = vectorizer.get_feature_names()
transformer = TfidfTransformer()
X_tfidf = transformer.fit_transform(X)

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic #%d:" % topic_idx)
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

# %%
nmf = NMF(n_components=100, init='random', random_state=0)
nmf.fit(X_tfidf)
print_top_words(nmf, feature_names, 12)
# Out:
# Topic #0:
# 03 2001 allen 01 pm phillip cc forwarded subject to hou am
# Topic #1:
# program trading chad track rotation bland resume ted risk interview train desks
# Topic #2:
# doc mime file system using attachment message ms pegasus compliant mailer davis
# Topic #3:
# com www http chnlownr hearme vc2 nytimes greenbuilder item pallen autoweb hemp
# Topic #4:
# maps 2000 07 6756 brodeur stephane 16 403 974 03 allen map
# Topic #5:
# rentroll lucy questions here going week 32 12 write 20a deposit apartment
# Topic #6:
# message sent original from 2001 phillip subject allen to monday fw mailto
# Topic #7:
# partnership would let like jacques engineer work know architect need agreements engineering
# Topic #8:
# ect hou 2000 allen pm 07 forwarded 11 cc subject 04 from
# Topic #9:
# distinguish detailing mark sells buys vs trades september spreadsheet socal 29 08
# Topic #10:
# attorney wholesale communication conf western activities 05 call ferc power asserted steffes
# Topic #11:
# 06 gas webcl1 ecthou hoskins nt brian password reports all west desk
# Topic #12:
# ees hou ect mail com robert na james erika dupre enron_development sce
# Topic #13:
# team selection christi form information email influence smith executive impact lrinet receipt
# Topic #14:
# shockwave m0 shockmachine net frogger shockwave1 com download asp arcade unsubscribe save
# Topic #15:
# power republicans bills utilities state bridge enronxgate sources issuance bond legislature billion
# Topic #16:
# 00 50 sat thru 10 power 2001 said bloomberg change pt outages
# Topic #17:
# worksheet alliance netback julie hello 04 men holiday gomez 11 2000 case
# Topic #18:
# patti randy scheduling time she group award pbr explosion prepare gay salary
# Topic #19:
# living across front deep porch gable addition area plan house story 25
# Topic #20:
# desk west assoc analysts celeste mid headcount trading the like would origination
# Topic #21:
# request approval 000000000067320 resource matt id smith com enron auth emaillink overdue
# Topic #22:
# equity profit budget construction builders schedule would split investment sm134 feel plan
# Topic #23:
# buyout bishops corner ltd project contracts claudia cash austin fee rr crocker
# Topic #24:
# strategy western tim materials session heizenrader briefing fallon attached charts 2000 belden
# Topic #25:
# lenhart randy matt gay janie tory ermis tholt south tara frank products
# Topic #26:
# buy downgraded initiated coverage upgraded 2001 strong 2000 nt lt neutral 04
# Topic #27:
# hotmail msn com explorer xls 2000 roll free gonzalez http stagecoachmama get
# Topic #28:
# trades physical juan index san financial september monthly 70 prices daily outliers
# Topic #29:
# director manager possible plan marketing barry west faith special commercial tori associate
# Topic #30:
# 713 fax 2391 646 853 7041 lee loan number application home 8626
# Topic #31:
# resumes rotating analyst andrea resend george phillip developments just three are attachment
# Topic #32:
# var trv west 2001 11 lowers current_efct_date toc_hide tv1exp stv1 report_cd report_name
# Topic #33:
# rr austin cbpres com richards xls cost george 02 sm134 draw2 proforma2
# Topic #34:
# 09 20 fyi showtimes 096 am 30pm 00pm section 15pm yahoo 45pm
# Topic #35:
# johnnie panels would panel thank estimates cost system general contractor purchasing within
# Topic #36:
# comments diego gas caps response price request san sarah draft please becky
# Topic #37:
# 512 smith 732 jsmith austintx jeff amf he 9728 751 mobile stage
# Topic #38:
# missed rent deposit 26 owes has still tomas 13 reaction paid clearing
# Topic #39:
# still online barney inteligence access service apea 204 press 228 do data
# Topic #40:
# accenture recipient mery prohibited delete sender contain meeting privileged brown sheri message
# Topic #41:
# 20 pira cross commodity study frank 01 region southwest hayden prospectus commodities
# Topic #42:
# loads prices load low november gas year us we 40000 equals telerate
# Topic #43:
# tweak format concessions slight buyout presents 1400 spreadsheet numbers summary the here
# Topic #44:
# new spreadsheet simplistic worse bullish q3 generation looks plants drop yet case
# Topic #45:
# request com resource id approve enron access 08 approval arsystem lucci srrs
# Topic #46:
# stage insurance policy the prorate info kuo cancel company appraiser dad signed
# Topic #47:
# book pipe admin option susan larry 02 issue night sally beck daily
# Topic #48:
# ect pdx hou sf generation tim enron_development jim michael belden mcdonald laird
# Topic #49:
# storage bid injection capacity daily withdrawal waha demand mmbtu assumptions gas model
# Topic #50:
# quotes george rahal phillip_k_allen acn financials basis acnpower 893 1803 703 power
# Topic #51:
# presentation trading slides track handouts topic overhead natural bring western gas mog
# Topic #52:
# shares stock distribution plan renee section psa account deferral payment restricted form
# Topic #53:
# position positions list consolidated tds ability physical deal issues project manager requirements
# Topic #54:
# meeting price commission delayed cap fixed doors closed morning behind discussions happens
# Topic #55:
# san marcos project formas pro look investors construction mentioned builder find would
# Topic #56:
# aec opal volumes 12 02 whitt allen ect 2001 pm phillip tyrell
# Topic #57:
# basis specialist sr east list central approved trader director wish systems renamed
# Topic #58:
# wsj interactive __________________________________ alert com http searchuser emailalert see business pl bin
# Topic #59:
# loans loan land 000 construction lot costs cost would investment improvement per
# Topic #60:
# resume buckley karen track interviews round analyst send trading may ashish mahajan
# Topic #61:
# image click iwon receive email free forgot unsubscribe amazon you future online
# Topic #62:
# project proforma westgate austin property severe 512 338 site xls lot as
# Topic #63:
# intelligence intelligencepress password publications ngi press mail index html http visit please
# Topic #64:
# test testing successful go way 8774820206 pagenetmessage rms 58 erms sell low
# Topic #65:
# points gas california talking christi delivery 12 market cost ferc proxy publication
# Topic #66:
# notice transwestern dec co pipeline 2000 new 12 13 et_noncritical_notice infopostings ets
# Topic #67:
# 000 actual 500 unwind spreads 600 669 paso el pay rock quotes
# Topic #68:
# hou ect meeting description scott 09 severude severson russ mills allan 2000
# Topic #69:
# facing weekly going issues regulatory is week conference included sure type make
# Topic #70:
# front might simple roof exterior porch reagan plans house place way 29
# Topic #71:
# can west site power access mcnary website thank he tim accessing active
# Topic #72:
# amendment 370 winstead 512 2836 msimpkins doc escrow simpkins michelle first agreement
# Topic #73:
# keith greg holst happy email phone call day derek receive updated kelly
# Topic #74:
# bid drawings construction kipp reagan attracted flores fha mix presence plans local
# Topic #75:
# enron na corp ect hr enronxgate hou mgusa outlook richard mark owa
# Topic #76:
# burnet jeff what deal phillip isssues stagecoach inspection closing property statement operating
# Topic #77:
# dexter eol id ngi guest steis bidweek password access intelligencepress griff shortly
# Topic #78:
# jacques draw quote release status wade craig what jeff phillip claudia confirm
# Topic #79:
# approval reports expense report days queue mgr awaiting waiting owner name your
# Topic #80:
# forecast here hydro systems wish 1st biop draft dsl 98 range estimate
# Topic #81:
# yahoo personals messenger do alberto watching __________________________________________________ nov me hear turned you
# Topic #82:
# socal sanjuan spread curves pepl prices chicago enough jed katy short hehub
# Topic #83:
# california load summary graphs data additional 05 dmccarty bcc 11 attempting demand
# Topic #84:
# prices files responses decreased rose illustrate supply fall response increased demand beginning
# Topic #85:
# yes calendar if no mm anyone please do does yy dd ipaq
# Topic #86:
# check brenda payment october second tossed know use let college another sept
# Topic #87:
# zdnet slink cgi http 8593142 com adeskb anchordesk chkpt stories zd xp
# Topic #88:
# grigsby mike distribution thank bloomberg please approve add list john phillip transwestern
# Topic #89:
# wade mary call today office later lucy day try get email philip
# Topic #90:
# million project appraisal cost financing interim around student estimates rental unit would
# Topic #91:
# alan kean steve request comnes 04 lay 27 ken wants pdx update
# Topic #92:
# sunone ectpdx navsetup ctatham westgasx htm index http address id pw pallen
# Topic #93:
# orders instructions painewebber or and ubspainewebber mail regarding notice 31 benotti muni
# Topic #94:
# meeting tomorrow ina jean mrha 30 scheduled fine status weekly talk rangel
# Topic #95:
# meetings ferc instructions works capitol benson connection thank eric capitolconnection butler video
# Topic #96:
# file showed open excel input email rents names back then lucy please
# Topic #97:
# property tenants paid week pay rent 260 lease raise nothing why improve
# Topic #98:
# re thanks inquiry respond how received ca help messenger are apt ok
# Topic #99:
# com filed version enron 13 bracepatt final 12 rebecca 2000 watkiss rrich
# ()

# %%
lda = LatentDirichletAllocation(n_topics=100, max_iter=5,
                                learning_method='online', learning_offset=50.,
                                random_state=0)

lda.fit(X)
print_top_words(lda, feature_names, 12)
# Out:
# Topic #0:
# ect hou 2000 00 scott 09 pm meeting phillip allen physical gas
# Topic #1:
# kind paine exclusive weber sdli rising eog jdsu exercising starting oil 3d
# Topic #2:
# quar psa major mega frequency accommodating technically marshall deffner gov rt governmental
# Topic #3:
# chance magazine resp homework professionals ease opportuni eb1672 sip recomm 5552 begun
# Topic #4:
# image change story full oil close nov 000 216 nmail 237 insight
# Topic #5:
# curves curve saved gd here drop night look improvements socal pulls menu
# Topic #6:
# save click oz garden saws icon reg folder phillip messenger mignons roehm
# Topic #7:
# 00 zdnet com http cgi slink 8593142 thru sat ct adeskb center
# Topic #8:
# project allen proforma com loans spy calculated estimat lowry opposite overdyke hou
# Topic #9:
# inter tuning 3175 comply gain 2101 advisor 981 prebid hdx options fronts
# Topic #10:
# curb motion weatherford density patterson compromise landowners seniors mcbride hughson craddock mihalkanin
# Topic #11:
# nwpl chicago katy permian pepl socal opal nymex hehub tv prompt 33
# Topic #12:
# ect hou phillip meeting 2000 09 pm allen scott no 00 hunter
# Topic #13:
# numbers holst receive phillip you call steve re request keith kean alan
# Topic #14:
# com phillip the please enron 2001 to would http allen www 000
# Topic #15:
# 00pm 09 showtimes 30pm 12 15pm 10 45pm image 10pm 11 05pm
# Topic #16:
# reams nenbaums garner marketers itsimazing marcia beautiful dogs boulder deefpbcjfcjbpbbihj 127 hawthorn
# Topic #17:
# prudency 2023 pgt term phillip would units 000 lot loans construction the
# Topic #18:
# violation board apartments mary lease resolved duties working tenants hotmail people lucy
# Topic #19:
# cpa fletch not related business good still think re sabas oppor motel
# Topic #20:
# sunone ectpdx htm navsetup ctatham index http westgasx pallen address use id
# Topic #21:
# 3d phillip 2000 allen 08 ect mark hou september forwarded com subject
# Topic #22:
# trades physical san juan index september paso el financial prices socal gas
# Topic #23:
# gas price cycle fixed customer mmcf 505 deal fw collar microturbine forward
# Topic #24:
# check unit august description statement checks lucy july 464 what labor bank
# Topic #25:
# trading re analyst track resume karen adrianne interviews buckley candidate interview may
# Topic #26:
# 3d ect would 000 loans enron the hou phillip lot loan site
# Topic #27:
# lime cement roman uses moore book david recommend history arry interesting pozzolonic
# Topic #28:
# meetings trip business would my ski try waterhouse even takes boat fun
# Topic #29:
# _e4bed334 software impress sa mailbox addicted losing integrate pound vogue dlgold irene
# Topic #30:
# origination dave category sparse names side members here ect hou john the
# Topic #31:
# list phillip ect 09 2000 allen market contact hou 11 mid loan
# Topic #32:
# com austin project phillip the allen property 2000 512 team severe christi
# Topic #33:
# var aeco sagewood etc is curve brokering re differently correlation mapped propose
# Topic #34:
# hou ect meeting pm 2000 09 00 allen 27 phillip description scott
# Topic #35:
# what we good latest phillip discussions chris eol pg regarding call x37041
# Topic #36:
# project austin proforma property the phillip this westgate week 338 would san
# Topic #37:
# phillip 00 the would gas need we new get week re project
# Topic #38:
# loan 000 construction the value loans would lot land costs fee partnership
# Topic #39:
# ect file data hou 2000 email enron space due john week seattle
# Topic #40:
# enron na ect took att1 please maple indigestion isions ron 26 296
# Topic #41:
# units duplex my built new different investor strong bid far 159 would
# Topic #42:
# progress email want budget phillip need how 00 it spreadsheets you files
# Topic #43:
# daily gas grigsby 37031 thank user password regarding guest information kathy friday
# Topic #44:
# request com enron 08 ect jeffrey approval paul 2000 shankman pm lucci
# Topic #45:
# saws garden carolyne designs project roehm icon secrets quilts chunky kieffer deer
# Topic #46:
# units million 000 reagan duplex he spoke thoughts sagewood almost are phillip
# Topic #47:
# 3d 09the networks nortel quarter results loss tax operations earnings ended revenues
# Topic #48:
# test testing successful 000 way would loan loans land hartford buick mercedes
# Topic #49:
# hotmail msn lucy stagecoachmama gonzalez private 56 daily kuo 08 apt ck
# Topic #50:
# brenda college send can phillip station address wallis hess sangle omeone beforehand
# Topic #51:
# ect enron yes if phillip calendar allen hou no email re to
# Topic #52:
# what message keith going greg apartment the back otherwise good work got
# Topic #53:
# enter domain hourly passwords keeps did expost cooper asking summary security add
# Topic #54:
# email com 2000 snapshot debe ated phillip marty 12 31 team spouses
# Topic #55:
# closing binding something signature atty estate vague document sound transaction bs pocket
# Topic #56:
# please phillip regulatory on note holding colleen mike re filing patti distribution
# Topic #57:
# ect hou meeting scott 2000 pm hunter phillip allen shively positions 00
# Topic #58:
# ect 09 hou 2001 phillip allen pm 2000 to enron subject am
# Topic #59:
# operates colder panasonic squad 1711 swf vanderhorst punishment offline h430297053x351634 mumm luding
# Topic #60:
# stanfield sept malin term casino sense ubid chips vegas county 2008 2006
# Topic #61:
# program feedback participant executive assessment influence impact participation survey important psa process
# Topic #62:
# requests clog denied 4nnjez coming why security re request hedges leading sc
# Topic #63:
# 15pm showtimes 45pm 00pm 30pm 10pm 40pm 05pm 35pm 25pm 20pm 50pm
# Topic #64:
# chelsea booked villa villas hands coach roll burnet phillip re happy brenda
# Topic #65:
# envoy wade vehicles vehicle gmc truck buy suv rebates 4wd buick stickers
# Topic #66:
# records tech fields billing zip ver disc admin shipping 00us 340 499
# Topic #67:
# bid kipp construction flores drawings reagan fha local strong mix unit financing
# Topic #68:
# eavesdropped think would steer heat innovation fs regan ball 377 hotter arrive
# Topic #69:
# our lynna sirloins renta ftse postwar consult vers appropriately golden undertake aded
# Topic #70:
# 000 would lot land loan total costs this loans com the please
# Topic #71:
# dogs dial unveiled tanding batt rooms windshield decreases cusack determine them oz
# Topic #72:
# he attend desk office friday transport phillip transportation model re managing ot
# Topic #73:
# would loan lot loans land 000 the austin project construction per westgate
# Topic #74:
# com mailto smith sent team information email phillip mike christi winstead message
# Topic #75:
# val army erika confirms 3949 east deemed markets 5243 rprise ocean llen
# Topic #76:
# position ect meeting plan re positions hou physical need consolidated manager project
# Topic #77:
# ect hou data the exodus 2000 power said center 09 enron internet
# Topic #78:
# 3ddeefpb approximate accrued mcgraw 09jp 7604 sewing kids emails strips fina carolyn
# Topic #79:
# turn jim123 200k marlene_huntsinger crowds deve umts kwh flags fly stdolelink restart
# Topic #80:
# column sheet rent roll formula letter add amount use mouse columns copy
# Topic #81:
# socal actual bidweek daily vs spreads basis gas swaps significant trading premium
# Topic #82:
# program participant enron assessment executive feedback com impact influence input phillip asked
# Topic #83:
# com enron allen westgate know 30 phillip 10 san please units let
# Topic #84:
# transwestern notice co pipeline juan distribution add san new re grigsby please
# Topic #85:
# 000 would com loan austin the land construction loans phillip 08 project
# Topic #86:
# 000 loan project land would lot costs construction this per austin the
# Topic #87:
# requested rights grant thanks stephanie eol approval paul your re please phillip
# Topic #88:
# ect team smith com phillip christi 2000 email 09 investment form land
# Topic #89:
# 000 loan would loans land construction the lot costs per value phillip
# Topic #90:
# manager associate commercial tori support kuykendall martin year desk cuilla like brad
# Topic #91:
# showtimes 15pm 00pm 45pm 30pm 10pm 05pm 20pm 35pm 55pm 40pm 50pm
# Topic #92:
# check description unit detail together 3428 phillip attached wrote lucy bank send
# Topic #93:
# medium commercial lp spreadsheet meter cheaper practice chance usage described showtimes excel
# Topic #94:
# britt choi wil targets reasons cylce aboard kulvinder af 2000 siebel cfp
# Topic #95:
# redeem disposition cuatro indicated 25pm dealing 2835127 flooded kulic 1321 entirely messerli
# Topic #96:
# trading re evaluation stop set can please expiration vision reuters phillip frame
# Topic #97:
# enron ect hou ees na corp enronxgate com 20 mail hr enron_development
# Topic #98:
# com request id enron http approval access please name resource td click
# Topic #99:
# password user enrononline guest page toubia mark shockwave 713 22nd id directions
# ()

# %%
lsa = TruncatedSVD(n_components=100)
lsa.fit(X) 
print_top_words(lsa, feature_names, 12)
print lsa.components_
# Out:
# Topic #0:
# ect enron hou enronxgate corp ees na com enron_development 09 20 allen
# Topic #1:
# 09 image 20 090 00 full story 10 09go com the 2001
# Topic #2:
# 00 ees com enron 2001 20 10 3d mail power pm na
# Topic #3:
# enron na corp hr outlook mgusa owa migration ees 09 access nyc
# Topic #4:
# ees com hou mail 20 sce http 01 cash cpuc richard the
# Topic #5:
# 3d 2001 networks tax us nortel net 30 2000 results loss operations
# Topic #6:
# com image http 00pm 12 the showtimes 30pm mail zdnet www phillip
# Topic #7:
# 10 2001 00pm showtimes 30pm 12 11 15pm image 45pm pm thru
# Topic #8:
# image ees 50 power 3d enronxgate prices change said story 00pm showtimes
# Topic #9:
# enronxgate image com 2001 mail 00 http thru sat zdnet ct london
# Topic #10:
# enronxgate 00pm showtimes 30pm 15pm 45pm mail 3d 12 com ees 00
# Topic #11:
# enronxgate 20 would the 000 loan buy loans costs cost 2001 land
# Topic #12:
# buy 20 downgraded 2000 coverage 2001 initiated strong http power upgraded 50
# Topic #13:
# 20 http zdnet www ect cgi com slink sce 00 yahoo td
# Topic #14:
# buy loans loan 000 land lot construction http downgraded costs ect corp
# Topic #15:
# email records phone name address included fax fields available billing tech buy
# Topic #16:
# iso power line the jones dow aes dj plants zdnet off wednesday
# Topic #17:
# zdnet http slink cgi ees 8593142 hou gas adeskb the make time
# Topic #18:
# td images width border src img gif http sportsline www height font
# Topic #19:
# gas utilities 10 prices natural storage td mail price energy images width
# Topic #20:
# million net 11 tax 2001 mail september american express financial quarter income
# Topic #21:
# item living jhtml shopping lc productid www gas http 11 clle style
# Topic #22:
# 11 ees provide please 17 09the 2001 contract information 12 review daily
# Topic #23:
# 2000 11 million meeting hou scott no response pm description gas company
# Topic #24:
# position 11 positions daily 2000 ability tds manager project consolidated physical issues
# Topic #25:
# 11 mail 20 position 17 gas 3d zdnet yahoo 01 to 18
# Topic #26:
# mail free click www the yahoo asp multexinvestor if report multex you
# Topic #27:
# republicans socal bridge bond sources mail state would billion loan may legislature
# Topic #28:
# mail yahoo item please living information shopping 09the provide jhtml contract project
# Topic #29:
# project austin proforma westgate 512 property 2000 week the as site xls
# Topic #30:
# data 2000 35 pm internet seattle mail center 05 pdx exodus power
# Topic #31:
# mail yahoo yesterday 90 75 13 67 2000 phillip forecasts provide daily
# Topic #32:
# 2000 data accenture the review seattle 10 center exodus stars john space
# Topic #33:
# yahoo time new mailto 07 0f 00pm you com sportsline autoweb org
# Topic #34:
# customer stars review average yahoo 10 12 the na call ferc time
# Topic #35:
# meeting this ferc accenture call na pdx mail www communication attorney western
# Topic #36:
# new pdx nytimes would autoweb section shares generation plan phillip credit get
# Topic #37:
# sportsline images sales accenture 2000 pdx http 12 nbsp 10 11 multexinvestor
# Topic #38:
# sportsline shares stock section images plan account hou distribution call sales re
# Topic #39:
# yahoo pdx stock shares time gov mailto account section demand org 000
# Topic #40:
# hr owa 2001 outlook corp request please available mailbox access 000 01
# Topic #41:
# buyout information if 2001 bishops ltd corner contracts total 03 yes keith
# Topic #42:
# request please 2000 if approval org shares section access this for resource
# Topic #43:
# mailto basis org specialist sr west www east sent hr director information
# Topic #44:
# specialist basis 2001 sr east yes director west list if autoweb accenture
# Topic #45:
# accenture basis 2000 specialist nytimes sr hou east section sheri time shares
# Topic #46:
# basis specialist sr request east would he director state click meeting west
# Topic #47:
# autoweb credit smith center access need news hr request 27 email phillip
# Topic #48:
# trades san juan index see we like hou week points physical 27
# Topic #49:
# time if pdx specialist cycle hr sr life basis ofo daily socal
# Topic #50:
# trades san request juan physical 27 instructions and 01 or index basis
# Topic #51:
# autoweb 12 hou cycle credit ofo instructions or and orders notice 2000
# Topic #52:
# request cycle day approval ofo nytimes id resource new usage smith am
# Topic #53:
# 03 org am or and trades gov 29 orders net market front
# Topic #54:
# autoweb time credit life today 8593142 would 2000 center allen href meeting
# Topic #55:
# meeting mailto cycle generation ofo shockwave allen state net am m0 day
# Topic #56:
# 01 org 02 day cycle gov 2001 week 12 houston ofo us
# Topic #57:
# christi smith email team we instructions need 31 12 fantasy selection internet
# Topic #58:
# 27 01 26 information change shockwave mailto 713 28 m0 cost scheduled
# Topic #59:
# org book price re would hr gov yes 04 hou bpa like
# Topic #60:
# 000 demand mwa hou 02 shockwave net life information reduction year 2001
# Topic #61:
# 17 clay smith kingsgate generation state earnings basin from 2001 salomon barney
# Topic #62:
# mailto would 01 epsa el paso 17 pdx price qfs if enron_development
# Topic #63:
# 25 22 12 am 30 thur price re 345 restore team us
# Topic #64:
# 17 price sat message 18 to we sent from see information 27
# Topic #65:
# request clay from kingsgate org basin information team www steve transport autoweb
# Topic #66:
# fantasy football revenue pros week start energy ll management game players optimization
# Topic #67:
# revenue pros book the you management storage 30 instructions optimization see demand
# Topic #68:
# 27 the pira us access 26 no smith study center scheduled 04
# Topic #69:
# mailto price file unit id click 000 hr mark yes project no
# Topic #70:
# would book 12 meeting like cost 17 01 18 yahoo smith profit
# Topic #71:
# earnings book est 2000 year mailto eps 27 fiscal next hr 04
# Topic #72:
# email qfs phillip revenue price pros hr 19 pg deal internet need
# Topic #73:
# the book 02 email recipient hr 2000 intended for wsj 05 basis
# Topic #74:
# 02 california meeting re 27 loan pira 18 this information commission 17
# Topic #75:
# click manager director 000 california id 02 27 west nmail need 216
# Topic #76:
# 02 would mark please file 08 email 28 john change autoweb smith
# Topic #77:
# 12 book file 000 27 christi http energy 26 get corp hr
# Topic #78:
# please first wsj west support change na desk interactive level email __________________________________
# Topic #79:
# book gas 02 change please plants account coal us susan qfs am
# Topic #80:
# would qfs the 26 to 01 pg wsj information click market interactive
# Topic #81:
# first email click pira 713 us new contract doc address amendment phillip
# Topic #82:
# email steve alan if 04 comnes cost internet sent support kean hr
# Topic #83:
# 000 04 price us book market today online change barney salomon get
# Topic #84:
# re smith george 2000 file sent accenture barney salomon jeff from yahoo
# Topic #85:
# we desk from internet access address pros revenue message physical id password
# Topic #86:
# 04 wsj interactive 000 market would __________________________________ call phillip customer re john
# Topic #87:
# 000 outlook re 01 owa susan desk 713 use houston access market
# Topic #88:
# pm john 01 us email george 03 rent michael closed trading new
# Topic #89:
# amendment need first 512 deed please winstead credit if hr robert 370
# Topic #90:
# 12 one in cc sf subject would change need from tech no
# Topic #91:
# am get free 000 10 01 11 02 mike email first physical
# Topic #92:
# please steve 30 richard qfs time physical phillip 27 update 000 new
# Topic #93:
# george 000 john information call 713 hr 2000 if time mark home
# Topic #94:
# 000 to pm michael corp access mike 08 physical this chris susan
# Topic #95:
# na to 2001 000 meeting allen mark enron_development would 2000 jeffrey email
# Topic #96:
# pm forwarded allen if new pdx desk qfs market change 26 na
# Topic #97:
# the phillip communications allen california michael call may to internet mail questions
# Topic #98:
# phillip center jeff 01 desk scott 02 susan chris 04 year robert
# Topic #99:
# phillip john 2000 michael 01 please corp update would energy email cal
# ()
# [[  1.10898889e-02   1.92448673e-03   6.05752085e-06 ...,   1.16106881e-05
#     1.53188431e-04   4.15934868e-06]
#  [  2.05358653e-02   8.30734316e-03   5.81095796e-07 ...,   1.84724155e-07
#     4.41474408e-05   6.82131289e-06]
#  [  4.90064312e-01   1.99036756e-02   6.44390946e-05 ...,   7.23619003e-06
#     1.84261489e-04   4.05774492e-05]
#  ...,
#  [  6.95159632e-02   2.45578200e-02   3.91607038e-03 ...,  -3.37174632e-05
#     2.36765435e-03   8.70384031e-04]
#  [  5.49339798e-02  -6.27714815e-02   4.69575896e-03 ...,  -2.04843504e-03
#     2.50937562e-03  -4.87618012e-04]
#  [  6.35060033e-02  -2.19830656e-01  -1.21872771e-02 ...,   2.25833915e-04
#    -2.28414149e-03   4.19965754e-04]]

# %%
print lsa.components_.shape
print lda.components_.shape
print nmf.components_.shape

print X.toarray().shape
print X_tfidf.toarray().shape
print len(processedCorpus)
# Out:
# (100, 17600)
# (100, 17600)
# (100, 17600)
# (3034, 17600)
# (3034, 17600)
# 3034

# %%
for t in corpus[:30]:
    sentences = sentenceDetector.tokenize(t)
    sentenceUnits = [ SentenceUnit(s) for s in sentences ]
    keyWords = textrank.textrank_keyword(sentenceUnits)
    print keyWords

# %%
sorted_x = sorted(keyWords.items(), key=operator.itemgetter(1), reverse=True)
print sorted_x
